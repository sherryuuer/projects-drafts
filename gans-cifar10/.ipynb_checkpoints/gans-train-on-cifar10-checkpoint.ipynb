# %% [markdown]
# # Build and train A Generative Adversarial Network

# %%
import os
import sys
cwd = os.getcwd()

#Numpy is linear algebra lbrary
import numpy as np
# Matplotlib is a visualizations library 
import matplotlib.pyplot as plt
# %matplotlib inline

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torch.autograd import Variable
from torchvision import utils
from torchvision import transforms
import torchvision.utils as vutils

# %%
batch_size=4

def load_data():
    
    #convert the images to tensor and normalized them
    transform = transforms.Compose([
         transforms.ToTensor(),
         transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
        ])

    # train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
    # test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
    train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=False, transform=transform)
    trainloader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size,
                                              shuffle=False, num_workers=1)
    return trainloader

# %%
trainloader = load_data()
next(iter(trainloader))[0].shape
# Out:
# torch.Size([4, 3, 32, 32])

# %% [markdown]
# ## Utility functions

# %%
def vectors_to_images(vectors):
    return vectors.view(vectors.size(0), 3, 32, 32)

def noise(size):
    '''
    Generates a 1-d vector of gaussian sampled random values
    '''
    n = Variable(torch.randn(size, 100))
    return n

def log_images(images, num_images, format='NCHW', normalize=True):
    '''
    input images are expected in format (NCHW)
    '''
    if type(images) == np.ndarray:
        images = torch.from_numpy(images)

    if format == 'NHWC':
        images = images.transpose(1, 3)

    

    # Make horizontal grid from image tensor
    horizontal_grid = vutils.make_grid(
        images, normalize=normalize, scale_each=True)
    # Make vertical grid from image tensor
    nrows = int(np.sqrt(num_images))
    grid = vutils.make_grid(
        images, nrow=nrows, normalize=True, scale_each=True)

    
    fig = plt.figure(figsize=(16, 16))
    plt.imshow(np.moveaxis(horizontal_grid.numpy(), 0, -1))
    plt.axis('off')
    # if plot_horizontal:
    #     display.display(plt.gcf())
    plt.show()

# %%
log_images(next(iter(trainloader))[0], 1)

# %% [markdown]
# ## Generator and Discriminator

# %%
class DiscriminatorNet(torch.nn.Module):
    """
    A three hidden-layer discriminative neural network
    """

    def __init__(self):
        super(DiscriminatorNet, self).__init__()
        n_features = 3072
        n_out = 1

        self.hidden0 = nn.Sequential(
            nn.Linear(n_features, 1024),
            nn.ReLU(),
            nn.Dropout(0.3)
        )
        self.hidden1 = nn.Sequential(
            nn.Linear(1024, 512),
            nn.ReLU(),
            nn.Dropout(0.3)
        )
        self.hidden2 = nn.Sequential(
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Dropout(0.3)
        )
        self.out = nn.Sequential(
            torch.nn.Linear(256, n_out),
            torch.nn.Sigmoid()
        )

    def forward(self, x):
        x = self.hidden0(x)
        x = self.hidden1(x)
        x = self.hidden2(x)
        x = self.out(x)
        return x


class GeneratorNet(torch.nn.Module):
    """
    A three hidden-layer generative neural network
    """

    def __init__(self):
        super(GeneratorNet, self).__init__()
        n_features = 100
        n_out = 3072

        self.hidden0 = nn.Sequential(
            nn.Linear(n_features, 256),
            nn.ReLU()
        )
        self.hidden1 = nn.Sequential(
            nn.Linear(256, 512),
            nn.ReLU()
        )
        self.hidden2 = nn.Sequential(
            nn.Linear(512, 1024),
            nn.ReLU()
        )

        self.out = nn.Sequential(
            nn.Linear(1024, n_out),
            nn.Tanh()
        )

    def forward(self, x):
        x = self.hidden0(x)
        x = self.hidden1(x)
        x = self.hidden2(x)
        x = self.out(x)
        return x

# %% [markdown]
# ## Train a GAN
#
# * Note 1: Can use the `log_images` function to plot the generated images.
# * Note 2: The training process is quite slow so I wouldn't expect to reach high levels of accuracy.

# %%
def train_discriminator(discriminator, optimizer, real_data, fake_data, loss):
    N = real_data.size(0)
    # Reset gradients
    optimizer.zero_grad()

    # Train on Real Data
    prediction_real = discriminator(real_data)
    # Calculate error and backpropagate
    error_real = loss(prediction_real, Variable(torch.ones(N, 1)))
    error_real.backward()

    # Train on Fake Data
    prediction_fake = discriminator(fake_data)
    # Calculate error and backpropagate
    error_fake = loss(prediction_fake, Variable(torch.zeros(N, 1)))
    error_fake.backward()

    # Update weights with gradients
    optimizer.step()

    # Return error and predictions for real and fake inputs
    return error_real + error_fake, prediction_real, prediction_fake


def train_generator(discriminator, optimizer, fake_data, loss):
    # Reset gradients
    N = fake_data.size(0)  
    
    # Sample noise and generate fake data
    optimizer.zero_grad()  
    
    # Calculate error and backpropagate
    prediction = discriminator(fake_data)  
    error = loss(prediction, Variable(torch.ones(N, 1)))
    
    # Update weights with gradients
    error.backward()  
    optimizer.step()  
    
    # Return error
    return error


def train():

    # Models, optimizers and losses
    discriminator = DiscriminatorNet()
    generator = GeneratorNet()
    loss_d = nn.BCELoss()
    loss_g = nn.BCELoss()
    d_optimizer = optim.Adam(discriminator.parameters(), 0.0002)
    g_optimizer = optim.Adam(generator.parameters(), 0.0002)

    data_loader = load_data()
    
    num_epochs = 1
    num_batches = len(data_loader)
    
    num_test_samples = 48
    test_noise = noise(num_test_samples)

    d_errors, g_errors = [], []
    d_pred_real_means, d_pred_fake_means = [], []
    for epoch in range(num_epochs):
        for n_batch, data in enumerate(data_loader):

            (real_batch, labels) = data
            N = real_batch.size(0)

            # 1. Train Discriminator
            real_data = real_batch.view(real_batch.size(0), -1)

            # Generate fake data and detach so gradients are not calculated for generator)
            latent_space_data = noise(N)
            fake_data = generator(latent_space_data).detach()

            d_error, d_pred_real, d_pred_fake = train_discriminator(discriminator, d_optimizer, real_data,
                                                                          fake_data,
                                                                          loss_d)
            # 2. Train Generator

            # Generate fake data TO train Generator
            latent_space_data = noise(N)
            fake_data = generator(latent_space_data)
            # Train G
            g_error = train_generator(discriminator, g_optimizer, fake_data, loss_g)  # Log batch error

            
            if n_batch % 50 == 0:
                print('Epoch: [{}/{}], Batch Num: [{}/{}]'.format(
                            epoch, num_epochs, n_batch, num_batches)
                    )
                print('Discriminator Loss: {:.4f}, Generator Loss: {:.4f}'.format(d_error, g_error))
                d_errors.append(d_error)
                g_errors.append(g_error)
                print('D(x): {:.4f}, D(G(z)): {:.4f}'.format(d_pred_real.mean(), d_pred_fake.mean()))
                d_pred_real_means.append(d_pred_real.mean())
                d_pred_fake_means.append(d_pred_fake.mean())
                print('------------------------------')
                
              
    
    print('Training finished')
    
    #Generate images
    test_images = vectors_to_images(generator(test_noise))
    test_images = test_images.data
    log_images(test_images,test_images.size()[0])

    return d_errors, g_errors, d_pred_real_means, d_pred_fake_means
    
d_errors, g_errors, d_pred_real_means, d_pred_fake_means = train()
# Out:
# Epoch: [0/1], Batch Num: [0/12500]
# Discriminator Loss: 1.3827, Generator Loss: 0.6713
# D(x): 0.5168, D(G(z)): 0.5145
# ------------------------------
# Epoch: [0/1], Batch Num: [50/12500]
# Discriminator Loss: 0.5194, Generator Loss: 1.8361
# D(x): 0.8660, D(G(z)): 0.2967
# ------------------------------
# Epoch: [0/1], Batch Num: [100/12500]
# Discriminator Loss: 0.5961, Generator Loss: 1.1553
# D(x): 0.9964, D(G(z)): 0.4432
# ------------------------------
# Epoch: [0/1], Batch Num: [150/12500]
# Discriminator Loss: 0.5726, Generator Loss: 1.0354
# D(x): 0.8911, D(G(z)): 0.3611
# ------------------------------
# Epoch: [0/1], Batch Num: [200/12500]
# Discriminator Loss: 0.2104, Generator Loss: 2.0086
# D(x): 0.9517, D(G(z)): 0.1463
# ------------------------------
# Epoch: [0/1], Batch Num: [250/12500]
# Discriminator Loss: 0.9814, Generator Loss: 1.3905
# D(x): 0.7726, D(G(z)): 0.2834
# ------------------------------
# Epoch: [0/1], Batch Num: [300/12500]
# Discriminator Loss: 1.2003, Generator Loss: 1.9161
# D(x): 0.8369, D(G(z)): 0.6054
# ------------------------------
# Epoch: [0/1], Batch Num: [350/12500]
# Discriminator Loss: 1.1176, Generator Loss: 1.1691
# D(x): 0.7210, D(G(z)): 0.3723
# ------------------------------
# Epoch: [0/1], Batch Num: [400/12500]
# Discriminator Loss: 2.1990, Generator Loss: 2.1851
# D(x): 0.7430, D(G(z)): 0.6038
# ------------------------------
# Epoch: [0/1], Batch Num: [450/12500]
# Discriminator Loss: 0.7222, Generator Loss: 3.0260
# D(x): 0.7007, D(G(z)): 0.2198
# ------------------------------
# Epoch: [0/1], Batch Num: [500/12500]
# Discriminator Loss: 0.7049, Generator Loss: 1.2581
# D(x): 0.8315, D(G(z)): 0.3447
# ------------------------------
# Epoch: [0/1], Batch Num: [550/12500]
# Discriminator Loss: 0.8829, Generator Loss: 0.8836
# D(x): 0.9986, D(G(z)): 0.5744
# ------------------------------
# Epoch: [0/1], Batch Num: [600/12500]
# Discriminator Loss: 0.5054, Generator Loss: 0.9355
# D(x): 0.9921, D(G(z)): 0.3848
# ------------------------------
# Epoch: [0/1], Batch Num: [650/12500]
# Discriminator Loss: 0.5044, Generator Loss: 1.1226
# D(x): 0.9781, D(G(z)): 0.3820
# ------------------------------
# Epoch: [0/1], Batch Num: [700/12500]
# Discriminator Loss: 0.4916, Generator Loss: 1.3085
# D(x): 0.9167, D(G(z)): 0.3233
# ------------------------------
# Epoch: [0/1], Batch Num: [750/12500]
# Discriminator Loss: 0.8410, Generator Loss: 1.7412
# D(x): 0.7891, D(G(z)): 0.3097
# ------------------------------
# Epoch: [0/1], Batch Num: [800/12500]
# Discriminator Loss: 0.2480, Generator Loss: 2.9959
# D(x): 0.9982, D(G(z)): 0.2133
# ------------------------------
# Epoch: [0/1], Batch Num: [850/12500]
# Discriminator Loss: 0.7979, Generator Loss: 1.8374
# D(x): 0.5947, D(G(z)): 0.1586
# ------------------------------
# Epoch: [0/1], Batch Num: [900/12500]
# Discriminator Loss: 0.1240, Generator Loss: 3.6984
# D(x): 0.9084, D(G(z)): 0.0168
# ------------------------------
# Epoch: [0/1], Batch Num: [950/12500]
# Discriminator Loss: 0.3745, Generator Loss: 2.0990
# D(x): 0.8556, D(G(z)): 0.1680
# ------------------------------
# Epoch: [0/1], Batch Num: [1000/12500]
# Discriminator Loss: 1.4984, Generator Loss: 0.4910
# D(x): 0.7937, D(G(z)): 0.6873
# ------------------------------
# Epoch: [0/1], Batch Num: [1050/12500]
# Discriminator Loss: 0.8315, Generator Loss: 1.5350
# D(x): 0.7669, D(G(z)): 0.3087
# ------------------------------
# Epoch: [0/1], Batch Num: [1100/12500]
# Discriminator Loss: 0.8269, Generator Loss: 1.0251
# D(x): 0.7850, D(G(z)): 0.4151
# ------------------------------
# Epoch: [0/1], Batch Num: [1150/12500]
# Discriminator Loss: 0.3077, Generator Loss: 1.7722
# D(x): 0.9469, D(G(z)): 0.2166
# ------------------------------
# Epoch: [0/1], Batch Num: [1200/12500]
# Discriminator Loss: 0.5053, Generator Loss: 0.9156
# D(x): 0.9565, D(G(z)): 0.3665
# ------------------------------
# Epoch: [0/1], Batch Num: [1250/12500]
# Discriminator Loss: 0.8496, Generator Loss: 1.1118
# D(x): 0.8924, D(G(z)): 0.5045
# ------------------------------
# Epoch: [0/1], Batch Num: [1300/12500]
# Discriminator Loss: 0.2924, Generator Loss: 1.9198
# D(x): 0.9762, D(G(z)): 0.2242
# ------------------------------
# Epoch: [0/1], Batch Num: [1350/12500]
# Discriminator Loss: 0.9545, Generator Loss: 0.7320
# D(x): 0.9848, D(G(z)): 0.6018
# ------------------------------
# Epoch: [0/1], Batch Num: [1400/12500]
# Discriminator Loss: 0.8942, Generator Loss: 0.7672
# D(x): 0.7579, D(G(z)): 0.4380
# ------------------------------
# Epoch: [0/1], Batch Num: [1450/12500]
# Discriminator Loss: 0.6166, Generator Loss: 0.9818
# D(x): 0.8605, D(G(z)): 0.3460
# ------------------------------
# Epoch: [0/1], Batch Num: [1500/12500]
# Discriminator Loss: 1.1260, Generator Loss: 1.9950
# D(x): 0.7554, D(G(z)): 0.1654
# ------------------------------
# Epoch: [0/1], Batch Num: [1550/12500]
# Discriminator Loss: 0.7124, Generator Loss: 0.9480
# D(x): 0.8765, D(G(z)): 0.4349
# ------------------------------
# Epoch: [0/1], Batch Num: [1600/12500]
# Discriminator Loss: 1.4244, Generator Loss: 1.0408
# D(x): 0.6137, D(G(z)): 0.4933
# ------------------------------
# Epoch: [0/1], Batch Num: [1650/12500]
# Discriminator Loss: 2.2235, Generator Loss: 0.6584
# D(x): 0.5558, D(G(z)): 0.6221
# ------------------------------
# Epoch: [0/1], Batch Num: [1700/12500]
# Discriminator Loss: 0.4538, Generator Loss: 1.7636
# D(x): 0.8166, D(G(z)): 0.2000
# ------------------------------
# Epoch: [0/1], Batch Num: [1750/12500]
# Discriminator Loss: 0.4844, Generator Loss: 1.3401
# D(x): 0.9411, D(G(z)): 0.3418
# ------------------------------
# Epoch: [0/1], Batch Num: [1800/12500]
# Discriminator Loss: 0.6566, Generator Loss: 2.3918
# D(x): 0.7222, D(G(z)): 0.1990
# ------------------------------
# Epoch: [0/1], Batch Num: [1850/12500]
# Discriminator Loss: 0.8777, Generator Loss: 1.4699
# D(x): 0.6813, D(G(z)): 0.3347
# ------------------------------
# Epoch: [0/1], Batch Num: [1900/12500]
# Discriminator Loss: 0.4591, Generator Loss: 0.9952
# D(x): 0.9708, D(G(z)): 0.3453
# ------------------------------
# Epoch: [0/1], Batch Num: [1950/12500]
# Discriminator Loss: 0.5584, Generator Loss: 1.6999
# D(x): 0.9984, D(G(z)): 0.4211
# ------------------------------
# Epoch: [0/1], Batch Num: [2000/12500]
# Discriminator Loss: 1.2291, Generator Loss: 1.6130
# D(x): 0.4830, D(G(z)): 0.2732
# ------------------------------
# Epoch: [0/1], Batch Num: [2050/12500]
# Discriminator Loss: 0.9438, Generator Loss: 1.3099
# D(x): 0.7387, D(G(z)): 0.4313
# ------------------------------
# Epoch: [0/1], Batch Num: [2100/12500]
# Discriminator Loss: 0.4982, Generator Loss: 1.1590
# D(x): 0.9495, D(G(z)): 0.3502
# ------------------------------
# Epoch: [0/1], Batch Num: [2150/12500]
# Discriminator Loss: 0.6578, Generator Loss: 1.0401
# D(x): 0.8344, D(G(z)): 0.3182
# ------------------------------
# Epoch: [0/1], Batch Num: [2200/12500]
# Discriminator Loss: 4.1608, Generator Loss: 1.0288
# D(x): 0.2591, D(G(z)): 0.4406
# ------------------------------
# Epoch: [0/1], Batch Num: [2250/12500]
# Discriminator Loss: 0.6503, Generator Loss: 1.0360
# D(x): 0.8928, D(G(z)): 0.4083
# ------------------------------
# Epoch: [0/1], Batch Num: [2300/12500]
# Discriminator Loss: 0.6970, Generator Loss: 1.2219
# D(x): 0.8853, D(G(z)): 0.4276
# ------------------------------
# Epoch: [0/1], Batch Num: [2350/12500]
# Discriminator Loss: 0.7955, Generator Loss: 0.7518
# D(x): 0.9941, D(G(z)): 0.5429
# ------------------------------
# Epoch: [0/1], Batch Num: [2400/12500]
# Discriminator Loss: 0.1502, Generator Loss: 2.5956
# D(x): 0.9975, D(G(z)): 0.1352
# ------------------------------
# Epoch: [0/1], Batch Num: [2450/12500]
# Discriminator Loss: 1.0452, Generator Loss: 0.4454
# D(x): 1.0000, D(G(z)): 0.6367
# ------------------------------
# Epoch: [0/1], Batch Num: [2500/12500]
# Discriminator Loss: 1.2926, Generator Loss: 1.0108
# D(x): 0.5231, D(G(z)): 0.4033
# ------------------------------
# Epoch: [0/1], Batch Num: [2550/12500]
# Discriminator Loss: 2.2034, Generator Loss: 1.2084
# D(x): 0.4768, D(G(z)): 0.6383
# ------------------------------
# Epoch: [0/1], Batch Num: [2600/12500]
# Discriminator Loss: 1.0656, Generator Loss: 1.1932
# D(x): 0.6889, D(G(z)): 0.4189
# ------------------------------
# Epoch: [0/1], Batch Num: [2650/12500]
# Discriminator Loss: 0.4312, Generator Loss: 1.6757
# D(x): 0.9876, D(G(z)): 0.3335
# ------------------------------
# Epoch: [0/1], Batch Num: [2700/12500]
# Discriminator Loss: 0.8764, Generator Loss: 1.0895
# D(x): 0.7907, D(G(z)): 0.3499
# ------------------------------
# Epoch: [0/1], Batch Num: [2750/12500]
# Discriminator Loss: 0.6968, Generator Loss: 1.2067
# D(x): 0.7172, D(G(z)): 0.2570
# ------------------------------
# Epoch: [0/1], Batch Num: [2800/12500]
# Discriminator Loss: 1.3892, Generator Loss: 0.9045
# D(x): 0.6652, D(G(z)): 0.4484
# ------------------------------
# Epoch: [0/1], Batch Num: [2850/12500]
# Discriminator Loss: 1.2392, Generator Loss: 1.5222
# D(x): 0.6499, D(G(z)): 0.4559
# ------------------------------
# Epoch: [0/1], Batch Num: [2900/12500]
# Discriminator Loss: 1.4453, Generator Loss: 1.3261
# D(x): 0.5650, D(G(z)): 0.2754
# ------------------------------
# Epoch: [0/1], Batch Num: [2950/12500]
# Discriminator Loss: 0.9070, Generator Loss: 1.5183
# D(x): 0.7481, D(G(z)): 0.4197
# ------------------------------
# Epoch: [0/1], Batch Num: [3000/12500]
# Discriminator Loss: 0.7005, Generator Loss: 1.5844
# D(x): 0.7754, D(G(z)): 0.3052
# ------------------------------
# Epoch: [0/1], Batch Num: [3050/12500]
# Discriminator Loss: 1.3128, Generator Loss: 1.0829
# D(x): 0.5213, D(G(z)): 0.3719
# ------------------------------
# Epoch: [0/1], Batch Num: [3100/12500]
# Discriminator Loss: 0.4100, Generator Loss: 1.1118
# D(x): 0.9972, D(G(z)): 0.3240
# ------------------------------
# Epoch: [0/1], Batch Num: [3150/12500]
# Discriminator Loss: 0.7209, Generator Loss: 1.3338
# D(x): 0.7592, D(G(z)): 0.3030
# ------------------------------
# Epoch: [0/1], Batch Num: [3200/12500]
# Discriminator Loss: 1.2121, Generator Loss: 1.0774
# D(x): 0.5382, D(G(z)): 0.3923
# ------------------------------
# Epoch: [0/1], Batch Num: [3250/12500]
# Discriminator Loss: 0.6258, Generator Loss: 0.9769
# D(x): 0.9505, D(G(z)): 0.4339
# ------------------------------
# Epoch: [0/1], Batch Num: [3300/12500]
# Discriminator Loss: 2.3180, Generator Loss: 0.9658
# D(x): 0.3537, D(G(z)): 0.4880
# ------------------------------
# Epoch: [0/1], Batch Num: [3350/12500]
# Discriminator Loss: 2.4723, Generator Loss: 1.0621
# D(x): 0.4452, D(G(z)): 0.4740
# ------------------------------
# Epoch: [0/1], Batch Num: [3400/12500]
# Discriminator Loss: 0.9070, Generator Loss: 1.0630
# D(x): 0.7334, D(G(z)): 0.4046
# ------------------------------
# Epoch: [0/1], Batch Num: [3450/12500]
# Discriminator Loss: 0.7062, Generator Loss: 1.3476
# D(x): 0.7005, D(G(z)): 0.2799
# ------------------------------
# Epoch: [0/1], Batch Num: [3500/12500]
# Discriminator Loss: 0.8835, Generator Loss: 0.8948
# D(x): 0.8098, D(G(z)): 0.4236
# ------------------------------
# Epoch: [0/1], Batch Num: [3550/12500]
# Discriminator Loss: 1.4268, Generator Loss: 0.5526
# D(x): 0.6424, D(G(z)): 0.6068
# ------------------------------
# Epoch: [0/1], Batch Num: [3600/12500]
# Discriminator Loss: 0.9834, Generator Loss: 3.0002
# D(x): 0.4915, D(G(z)): 0.1728
# ------------------------------
# Epoch: [0/1], Batch Num: [3650/12500]
# Discriminator Loss: 1.1988, Generator Loss: 0.7687
# D(x): 0.6650, D(G(z)): 0.5317
# ------------------------------
# Epoch: [0/1], Batch Num: [3700/12500]
# Discriminator Loss: 1.1524, Generator Loss: 0.3380
# D(x): 0.9286, D(G(z)): 0.6348
# ------------------------------
# Epoch: [0/1], Batch Num: [3750/12500]
# Discriminator Loss: 0.9055, Generator Loss: 0.7649
# D(x): 0.8389, D(G(z)): 0.4894
# ------------------------------
# Epoch: [0/1], Batch Num: [3800/12500]
# Discriminator Loss: 0.3278, Generator Loss: 2.2253
# D(x): 0.8726, D(G(z)): 0.1483
# ------------------------------
# Epoch: [0/1], Batch Num: [3850/12500]
# Discriminator Loss: 0.6984, Generator Loss: 1.2637
# D(x): 0.9222, D(G(z)): 0.4527
# ------------------------------
# Epoch: [0/1], Batch Num: [3900/12500]
# Discriminator Loss: 0.9609, Generator Loss: 2.8605
# D(x): 0.4965, D(G(z)): 0.1311
# ------------------------------
# Epoch: [0/1], Batch Num: [3950/12500]
# Discriminator Loss: 1.1553, Generator Loss: 0.7348
# D(x): 0.6439, D(G(z)): 0.4802
# ------------------------------
# Epoch: [0/1], Batch Num: [4000/12500]
# Discriminator Loss: 0.6800, Generator Loss: 0.9506
# D(x): 0.9107, D(G(z)): 0.4413
# ------------------------------
# Epoch: [0/1], Batch Num: [4050/12500]
# Discriminator Loss: 3.5350, Generator Loss: 1.4393
# D(x): 0.5717, D(G(z)): 0.2074
# ------------------------------
# Epoch: [0/1], Batch Num: [4100/12500]
# Discriminator Loss: 0.9144, Generator Loss: 0.8623
# D(x): 0.7350, D(G(z)): 0.4168
# ------------------------------
# Epoch: [0/1], Batch Num: [4150/12500]
# Discriminator Loss: 0.8397, Generator Loss: 2.5573
# D(x): 0.6015, D(G(z)): 0.2234
# ------------------------------
# Epoch: [0/1], Batch Num: [4200/12500]
# Discriminator Loss: 1.3678, Generator Loss: 0.8259
# D(x): 0.5817, D(G(z)): 0.4628
# ------------------------------
# Epoch: [0/1], Batch Num: [4250/12500]
# Discriminator Loss: 1.2312, Generator Loss: 0.7648
# D(x): 0.5070, D(G(z)): 0.3454
# ------------------------------
# Epoch: [0/1], Batch Num: [4300/12500]
# Discriminator Loss: 1.7985, Generator Loss: 1.0247
# D(x): 0.6980, D(G(z)): 0.3398
# ------------------------------
# Epoch: [0/1], Batch Num: [4350/12500]
# Discriminator Loss: 0.5103, Generator Loss: 1.3263
# D(x): 0.8376, D(G(z)): 0.2504
# ------------------------------
# Epoch: [0/1], Batch Num: [4400/12500]
# Discriminator Loss: 0.5099, Generator Loss: 2.8750
# D(x): 0.8223, D(G(z)): 0.1873
# ------------------------------
# Epoch: [0/1], Batch Num: [4450/12500]
# Discriminator Loss: 1.9154, Generator Loss: 0.9180
# D(x): 0.7355, D(G(z)): 0.3030
# ------------------------------
# Epoch: [0/1], Batch Num: [4500/12500]
# Discriminator Loss: 0.6776, Generator Loss: 2.5848
# D(x): 0.7756, D(G(z)): 0.2117
# ------------------------------
# Epoch: [0/1], Batch Num: [4550/12500]
# Discriminator Loss: 1.1498, Generator Loss: 0.8983
# D(x): 0.7182, D(G(z)): 0.4033
# ------------------------------
# Epoch: [0/1], Batch Num: [4600/12500]
# Discriminator Loss: 0.6248, Generator Loss: 1.0482
# D(x): 0.8784, D(G(z)): 0.3787
# ------------------------------
# Epoch: [0/1], Batch Num: [4650/12500]
# Discriminator Loss: 0.3427, Generator Loss: 1.9482
# D(x): 0.9581, D(G(z)): 0.2497
# ------------------------------
# Epoch: [0/1], Batch Num: [4700/12500]
# Discriminator Loss: 0.5394, Generator Loss: 1.1155
# D(x): 0.9893, D(G(z)): 0.4091
# ------------------------------
# Epoch: [0/1], Batch Num: [4750/12500]
# Discriminator Loss: 1.9722, Generator Loss: 1.0212
# D(x): 0.3788, D(G(z)): 0.4537
# ------------------------------
# Epoch: [0/1], Batch Num: [4800/12500]
# Discriminator Loss: 0.3934, Generator Loss: 1.3067
# D(x): 0.9385, D(G(z)): 0.2745
# ------------------------------
# Epoch: [0/1], Batch Num: [4850/12500]
# Discriminator Loss: 0.4722, Generator Loss: 1.2492
# D(x): 0.9944, D(G(z)): 0.3673
# ------------------------------
# Epoch: [0/1], Batch Num: [4900/12500]
# Discriminator Loss: 0.3623, Generator Loss: 2.6793
# D(x): 0.9789, D(G(z)): 0.2818
# ------------------------------
# Epoch: [0/1], Batch Num: [4950/12500]
# Discriminator Loss: 0.5504, Generator Loss: 0.9215
# D(x): 0.9997, D(G(z)): 0.4193
# ------------------------------
# Epoch: [0/1], Batch Num: [5000/12500]
# Discriminator Loss: 0.4660, Generator Loss: 2.0564
# D(x): 0.8981, D(G(z)): 0.2565
# ------------------------------
# Epoch: [0/1], Batch Num: [5050/12500]
# Discriminator Loss: 1.3974, Generator Loss: 1.8559
# D(x): 0.7270, D(G(z)): 0.2623
# ------------------------------
# Epoch: [0/1], Batch Num: [5100/12500]
# Discriminator Loss: 0.6505, Generator Loss: 0.9203
# D(x): 0.8854, D(G(z)): 0.3967
# ------------------------------
# Epoch: [0/1], Batch Num: [5150/12500]
# Discriminator Loss: 0.8129, Generator Loss: 1.8532
# D(x): 0.7440, D(G(z)): 0.2853
# ------------------------------
# Epoch: [0/1], Batch Num: [5200/12500]
# Discriminator Loss: 0.8891, Generator Loss: 1.2210
# D(x): 0.6405, D(G(z)): 0.2705
# ------------------------------
# Epoch: [0/1], Batch Num: [5250/12500]
# Discriminator Loss: 0.6023, Generator Loss: 1.5786
# D(x): 0.8119, D(G(z)): 0.2427
# ------------------------------
# Epoch: [0/1], Batch Num: [5300/12500]
# Discriminator Loss: 0.9500, Generator Loss: 1.6914
# D(x): 0.6943, D(G(z)): 0.1805
# ------------------------------
# Epoch: [0/1], Batch Num: [5350/12500]
# Discriminator Loss: 0.4373, Generator Loss: 1.4951
# D(x): 0.8909, D(G(z)): 0.2526
# ------------------------------
# Epoch: [0/1], Batch Num: [5400/12500]
# Discriminator Loss: 0.7432, Generator Loss: 1.6394
# D(x): 0.7219, D(G(z)): 0.2948
# ------------------------------
# Epoch: [0/1], Batch Num: [5450/12500]
# Discriminator Loss: 0.8466, Generator Loss: 1.2278
# D(x): 0.7101, D(G(z)): 0.3264
# ------------------------------
# Epoch: [0/1], Batch Num: [5500/12500]
# Discriminator Loss: 0.1570, Generator Loss: 1.5423
# D(x): 0.9999, D(G(z)): 0.1426
# ------------------------------
# Epoch: [0/1], Batch Num: [5550/12500]
# Discriminator Loss: 0.8550, Generator Loss: 1.1783
# D(x): 0.6867, D(G(z)): 0.3046
# ------------------------------
# Epoch: [0/1], Batch Num: [5600/12500]
# Discriminator Loss: 0.4556, Generator Loss: 1.0102
# D(x): 0.9927, D(G(z)): 0.3595
# ------------------------------
# Epoch: [0/1], Batch Num: [5650/12500]
# Discriminator Loss: 0.6712, Generator Loss: 1.1884
# D(x): 0.9284, D(G(z)): 0.4282
# ------------------------------
# Epoch: [0/1], Batch Num: [5700/12500]
# Discriminator Loss: 0.9124, Generator Loss: 0.9244
# D(x): 0.9999, D(G(z)): 0.5775
# ------------------------------
# Epoch: [0/1], Batch Num: [5750/12500]
# Discriminator Loss: 0.1899, Generator Loss: 1.6131
# D(x): 0.9863, D(G(z)): 0.1590
# ------------------------------
# Epoch: [0/1], Batch Num: [5800/12500]
# Discriminator Loss: 0.3295, Generator Loss: 2.0890
# D(x): 1.0000, D(G(z)): 0.2680
# ------------------------------
# Epoch: [0/1], Batch Num: [5850/12500]
# Discriminator Loss: 0.4337, Generator Loss: 1.2341
# D(x): 0.9484, D(G(z)): 0.3151
# ------------------------------
# Epoch: [0/1], Batch Num: [5900/12500]
# Discriminator Loss: 0.7594, Generator Loss: 2.0557
# D(x): 0.7737, D(G(z)): 0.2981
# ------------------------------
# Epoch: [0/1], Batch Num: [5950/12500]
# Discriminator Loss: 0.5014, Generator Loss: 1.6083
# D(x): 0.8300, D(G(z)): 0.2278
# ------------------------------
# Epoch: [0/1], Batch Num: [6000/12500]
# Discriminator Loss: 1.3174, Generator Loss: 0.9664
# D(x): 0.6521, D(G(z)): 0.4282
# ------------------------------
# Epoch: [0/1], Batch Num: [6050/12500]
# Discriminator Loss: 0.2345, Generator Loss: 2.0165
# D(x): 1.0000, D(G(z)): 0.2048
# ------------------------------
# Epoch: [0/1], Batch Num: [6100/12500]
# Discriminator Loss: 1.3812, Generator Loss: 1.6727
# D(x): 0.6700, D(G(z)): 0.1950
# ------------------------------
# Epoch: [0/1], Batch Num: [6150/12500]
# Discriminator Loss: 0.8050, Generator Loss: 0.9388
# D(x): 0.8741, D(G(z)): 0.4589
# ------------------------------
# Epoch: [0/1], Batch Num: [6200/12500]
# Discriminator Loss: 0.1300, Generator Loss: 2.3560
# D(x): 0.9998, D(G(z)): 0.1205
# ------------------------------
# Epoch: [0/1], Batch Num: [6250/12500]
# Discriminator Loss: 0.2876, Generator Loss: 1.8585
# D(x): 0.9977, D(G(z)): 0.2475
# ------------------------------
# Epoch: [0/1], Batch Num: [6300/12500]
# Discriminator Loss: 0.8093, Generator Loss: 1.3063
# D(x): 0.7895, D(G(z)): 0.2968
# ------------------------------
# Epoch: [0/1], Batch Num: [6350/12500]
# Discriminator Loss: 0.9210, Generator Loss: 1.0564
# D(x): 0.6645, D(G(z)): 0.3705
# ------------------------------
# Epoch: [0/1], Batch Num: [6400/12500]
# Discriminator Loss: 0.3565, Generator Loss: 1.1025
# D(x): 0.9848, D(G(z)): 0.2847
# ------------------------------
# Epoch: [0/1], Batch Num: [6450/12500]
# Discriminator Loss: 0.3475, Generator Loss: 1.3020
# D(x): 0.9954, D(G(z)): 0.2848
# ------------------------------
# Epoch: [0/1], Batch Num: [6500/12500]
# Discriminator Loss: 0.4004, Generator Loss: 1.2890
# D(x): 0.9927, D(G(z)): 0.3230
# ------------------------------
# Epoch: [0/1], Batch Num: [6550/12500]
# Discriminator Loss: 0.2725, Generator Loss: 1.8546
# D(x): 0.8877, D(G(z)): 0.1375
# ------------------------------
# Epoch: [0/1], Batch Num: [6600/12500]
# Discriminator Loss: 0.2289, Generator Loss: 1.6032
# D(x): 1.0000, D(G(z)): 0.2018
# ------------------------------
# Epoch: [0/1], Batch Num: [6650/12500]
# Discriminator Loss: 0.7229, Generator Loss: 1.3436
# D(x): 0.8473, D(G(z)): 0.4123
# ------------------------------
# Epoch: [0/1], Batch Num: [6700/12500]
# Discriminator Loss: 0.3871, Generator Loss: 1.3554
# D(x): 0.9686, D(G(z)): 0.2929
# ------------------------------
# Epoch: [0/1], Batch Num: [6750/12500]
# Discriminator Loss: 0.2548, Generator Loss: 2.1870
# D(x): 0.9440, D(G(z)): 0.1722
# ------------------------------
# Epoch: [0/1], Batch Num: [6800/12500]
# Discriminator Loss: 0.4624, Generator Loss: 1.5077
# D(x): 0.8834, D(G(z)): 0.2743
# ------------------------------
# Epoch: [0/1], Batch Num: [6850/12500]
# Discriminator Loss: 0.5567, Generator Loss: 1.2920
# D(x): 0.8950, D(G(z)): 0.3437
# ------------------------------
# Epoch: [0/1], Batch Num: [6900/12500]
# Discriminator Loss: 0.4419, Generator Loss: 1.2863
# D(x): 1.0000, D(G(z)): 0.3433
# ------------------------------
# Epoch: [0/1], Batch Num: [6950/12500]
# Discriminator Loss: 0.1506, Generator Loss: 2.4050
# D(x): 1.0000, D(G(z)): 0.1388
# ------------------------------
# Epoch: [0/1], Batch Num: [7000/12500]
# Discriminator Loss: 0.2778, Generator Loss: 1.5437
# D(x): 0.9988, D(G(z)): 0.2411
# ------------------------------
# Epoch: [0/1], Batch Num: [7050/12500]
# Discriminator Loss: 0.6197, Generator Loss: 1.4221
# D(x): 0.7904, D(G(z)): 0.2643
# ------------------------------
# Epoch: [0/1], Batch Num: [7100/12500]
# Discriminator Loss: 0.3224, Generator Loss: 1.6040
# D(x): 0.8986, D(G(z)): 0.1744
# ------------------------------
# Epoch: [0/1], Batch Num: [7150/12500]
# Discriminator Loss: 0.2409, Generator Loss: 2.3091
# D(x): 0.9813, D(G(z)): 0.1958
# ------------------------------
# Epoch: [0/1], Batch Num: [7200/12500]
# Discriminator Loss: 0.2831, Generator Loss: 1.8590
# D(x): 0.9936, D(G(z)): 0.2405
# ------------------------------
# Epoch: [0/1], Batch Num: [7250/12500]
# Discriminator Loss: 0.2083, Generator Loss: 1.8939
# D(x): 0.9823, D(G(z)): 0.1713
# ------------------------------
# Epoch: [0/1], Batch Num: [7300/12500]
# Discriminator Loss: 0.1469, Generator Loss: 2.7145
# D(x): 0.9952, D(G(z)): 0.1312
# ------------------------------
# Epoch: [0/1], Batch Num: [7350/12500]
# Discriminator Loss: 0.2201, Generator Loss: 4.1739
# D(x): 0.9102, D(G(z)): 0.1000
# ------------------------------
# Epoch: [0/1], Batch Num: [7400/12500]
# Discriminator Loss: 0.3270, Generator Loss: 1.8559
# D(x): 0.9829, D(G(z)): 0.2584
# ------------------------------
# Epoch: [0/1], Batch Num: [7450/12500]
# Discriminator Loss: 0.1514, Generator Loss: 3.4174
# D(x): 0.9980, D(G(z)): 0.1372
# ------------------------------
# Epoch: [0/1], Batch Num: [7500/12500]
# Discriminator Loss: 1.2892, Generator Loss: 2.3876
# D(x): 0.7529, D(G(z)): 0.1567
# ------------------------------
# Epoch: [0/1], Batch Num: [7550/12500]
# Discriminator Loss: 1.2509, Generator Loss: 0.8278
# D(x): 1.0000, D(G(z)): 0.6892
# ------------------------------
# Epoch: [0/1], Batch Num: [7600/12500]
# Discriminator Loss: 0.3027, Generator Loss: 1.8126
# D(x): 0.9742, D(G(z)): 0.2344
# ------------------------------
# Epoch: [0/1], Batch Num: [7650/12500]
# Discriminator Loss: 1.5902, Generator Loss: 1.2930
# D(x): 0.5434, D(G(z)): 0.3107
# ------------------------------
# Epoch: [0/1], Batch Num: [7700/12500]
# Discriminator Loss: 0.3460, Generator Loss: 1.8311
# D(x): 0.9638, D(G(z)): 0.2543
# ------------------------------
# Epoch: [0/1], Batch Num: [7750/12500]
# Discriminator Loss: 0.4062, Generator Loss: 1.6130
# D(x): 0.9175, D(G(z)): 0.2617
# ------------------------------
# Epoch: [0/1], Batch Num: [7800/12500]
# Discriminator Loss: 0.6715, Generator Loss: 1.6626
# D(x): 0.7510, D(G(z)): 0.2200
# ------------------------------
# Epoch: [0/1], Batch Num: [7850/12500]
# Discriminator Loss: 0.2886, Generator Loss: 1.3526
# D(x): 0.9811, D(G(z)): 0.2345
# ------------------------------
# Epoch: [0/1], Batch Num: [7900/12500]
# Discriminator Loss: 0.1478, Generator Loss: 1.5426
# D(x): 0.9994, D(G(z)): 0.1363
# ------------------------------
# Epoch: [0/1], Batch Num: [7950/12500]
# Discriminator Loss: 0.7188, Generator Loss: 1.6867
# D(x): 0.7429, D(G(z)): 0.1936
# ------------------------------
# Epoch: [0/1], Batch Num: [8000/12500]
# Discriminator Loss: 0.2775, Generator Loss: 1.6743
# D(x): 0.9747, D(G(z)): 0.2205
# ------------------------------
# Epoch: [0/1], Batch Num: [8050/12500]
# Discriminator Loss: 0.4362, Generator Loss: 1.6352
# D(x): 0.8596, D(G(z)): 0.2038
# ------------------------------
# Epoch: [0/1], Batch Num: [8100/12500]
# Discriminator Loss: 0.2188, Generator Loss: 2.1525
# D(x): 0.9996, D(G(z)): 0.1840
# ------------------------------
# Epoch: [0/1], Batch Num: [8150/12500]
# Discriminator Loss: 0.7574, Generator Loss: 2.3700
# D(x): 0.6645, D(G(z)): 0.1755
# ------------------------------
# Epoch: [0/1], Batch Num: [8200/12500]
# Discriminator Loss: 0.1596, Generator Loss: 2.8606
# D(x): 0.9963, D(G(z)): 0.1414
# ------------------------------
# Epoch: [0/1], Batch Num: [8250/12500]
# Discriminator Loss: 0.1755, Generator Loss: 2.2938
# D(x): 1.0000, D(G(z)): 0.1513
# ------------------------------
# Epoch: [0/1], Batch Num: [8300/12500]
# Discriminator Loss: 0.1549, Generator Loss: 1.5868
# D(x): 0.9999, D(G(z)): 0.1422
# ------------------------------
# Epoch: [0/1], Batch Num: [8350/12500]
# Discriminator Loss: 0.3998, Generator Loss: 1.4610
# D(x): 0.9520, D(G(z)): 0.2769
# ------------------------------
# Epoch: [0/1], Batch Num: [8400/12500]
# Discriminator Loss: 0.4231, Generator Loss: 1.2848
# D(x): 1.0000, D(G(z)): 0.2942
# ------------------------------
# Epoch: [0/1], Batch Num: [8450/12500]
# Discriminator Loss: 0.2915, Generator Loss: 1.8137
# D(x): 0.9984, D(G(z)): 0.2509
# ------------------------------
# Epoch: [0/1], Batch Num: [8500/12500]
# Discriminator Loss: 0.2440, Generator Loss: 1.5016
# D(x): 0.9999, D(G(z)): 0.2145
# ------------------------------
# Epoch: [0/1], Batch Num: [8550/12500]
# Discriminator Loss: 0.4310, Generator Loss: 2.0769
# D(x): 0.8455, D(G(z)): 0.1993
# ------------------------------
# Epoch: [0/1], Batch Num: [8600/12500]
# Discriminator Loss: 0.2120, Generator Loss: 1.8837
# D(x): 0.9978, D(G(z)): 0.1859
# ------------------------------
# Epoch: [0/1], Batch Num: [8650/12500]
# Discriminator Loss: 0.4362, Generator Loss: 1.5160
# D(x): 0.9991, D(G(z)): 0.3417
# ------------------------------
# Epoch: [0/1], Batch Num: [8700/12500]
# Discriminator Loss: 0.2975, Generator Loss: 1.7854
# D(x): 0.9700, D(G(z)): 0.2298
# ------------------------------
# Epoch: [0/1], Batch Num: [8750/12500]
# Discriminator Loss: 0.2304, Generator Loss: 1.3978
# D(x): 1.0000, D(G(z)): 0.2053
# ------------------------------
# Epoch: [0/1], Batch Num: [8800/12500]
# Discriminator Loss: 0.4145, Generator Loss: 1.6304
# D(x): 0.9276, D(G(z)): 0.2663
# ------------------------------
# Epoch: [0/1], Batch Num: [8850/12500]
# Discriminator Loss: 0.1307, Generator Loss: 1.7949
# D(x): 1.0000, D(G(z)): 0.1208
# ------------------------------
# Epoch: [0/1], Batch Num: [8900/12500]
# Discriminator Loss: 0.2979, Generator Loss: 1.6877
# D(x): 0.9775, D(G(z)): 0.2388
# ------------------------------
# Epoch: [0/1], Batch Num: [8950/12500]
# Discriminator Loss: 0.0609, Generator Loss: 2.7311
# D(x): 1.0000, D(G(z)): 0.0590
# ------------------------------
# Epoch: [0/1], Batch Num: [9000/12500]
# Discriminator Loss: 0.1899, Generator Loss: 3.0056
# D(x): 0.9010, D(G(z)): 0.0697
# ------------------------------
# Epoch: [0/1], Batch Num: [9050/12500]
# Discriminator Loss: 0.1420, Generator Loss: 2.6654
# D(x): 0.9843, D(G(z)): 0.1166
# ------------------------------
# Epoch: [0/1], Batch Num: [9100/12500]
# Discriminator Loss: 0.1926, Generator Loss: 2.2004
# D(x): 0.9997, D(G(z)): 0.1724
# ------------------------------
# Epoch: [0/1], Batch Num: [9150/12500]
# Discriminator Loss: 0.4765, Generator Loss: 1.4840
# D(x): 0.9812, D(G(z)): 0.3576
# ------------------------------
# Epoch: [0/1], Batch Num: [9200/12500]
# Discriminator Loss: 0.5974, Generator Loss: 1.7640
# D(x): 0.7040, D(G(z)): 0.1346
# ------------------------------
# Epoch: [0/1], Batch Num: [9250/12500]
# Discriminator Loss: 0.2313, Generator Loss: 2.7530
# D(x): 0.8983, D(G(z)): 0.1009
# ------------------------------
# Epoch: [0/1], Batch Num: [9300/12500]
# Discriminator Loss: 0.7064, Generator Loss: 1.9932
# D(x): 0.7752, D(G(z)): 0.1482
# ------------------------------
# Epoch: [0/1], Batch Num: [9350/12500]
# Discriminator Loss: 1.3503, Generator Loss: 1.8166
# D(x): 0.7549, D(G(z)): 0.3076
# ------------------------------
# Epoch: [0/1], Batch Num: [9400/12500]
# Discriminator Loss: 1.4812, Generator Loss: 1.8060
# D(x): 0.5433, D(G(z)): 0.1675
# ------------------------------
# Epoch: [0/1], Batch Num: [9450/12500]
# Discriminator Loss: 1.5218, Generator Loss: 3.1524
# D(x): 0.7155, D(G(z)): 0.0610
# ------------------------------
# Epoch: [0/1], Batch Num: [9500/12500]
# Discriminator Loss: 0.8711, Generator Loss: 1.3518
# D(x): 0.8542, D(G(z)): 0.3877
# ------------------------------
# Epoch: [0/1], Batch Num: [9550/12500]
# Discriminator Loss: 0.1725, Generator Loss: 1.7705
# D(x): 1.0000, D(G(z)): 0.1584
# ------------------------------
# Epoch: [0/1], Batch Num: [9600/12500]
# Discriminator Loss: 0.2922, Generator Loss: 1.3448
# D(x): 0.9994, D(G(z)): 0.2493
# ------------------------------
# Epoch: [0/1], Batch Num: [9650/12500]
# Discriminator Loss: 0.7236, Generator Loss: 1.7981
# D(x): 0.8142, D(G(z)): 0.3053
# ------------------------------
# Epoch: [0/1], Batch Num: [9700/12500]
# Discriminator Loss: 0.2945, Generator Loss: 1.5357
# D(x): 0.9989, D(G(z)): 0.2486
# ------------------------------
# Epoch: [0/1], Batch Num: [9750/12500]
# Discriminator Loss: 0.2226, Generator Loss: 2.3126
# D(x): 0.9945, D(G(z)): 0.1817
# ------------------------------
# Epoch: [0/1], Batch Num: [9800/12500]
# Discriminator Loss: 0.7343, Generator Loss: 1.6819
# D(x): 0.7980, D(G(z)): 0.2808
# ------------------------------
# Epoch: [0/1], Batch Num: [9850/12500]
# Discriminator Loss: 0.1719, Generator Loss: 2.2898
# D(x): 1.0000, D(G(z)): 0.1565
# ------------------------------
# Epoch: [0/1], Batch Num: [9900/12500]
# Discriminator Loss: 0.4881, Generator Loss: 1.4575
# D(x): 0.9985, D(G(z)): 0.3473
# ------------------------------
# Epoch: [0/1], Batch Num: [9950/12500]
# Discriminator Loss: 0.3533, Generator Loss: 1.5631
# D(x): 0.9918, D(G(z)): 0.2697
# ------------------------------
# Epoch: [0/1], Batch Num: [10000/12500]
# Discriminator Loss: 1.1513, Generator Loss: 1.1848
# D(x): 0.5334, D(G(z)): 0.2199
# ------------------------------
# Epoch: [0/1], Batch Num: [10050/12500]
# Discriminator Loss: 0.4860, Generator Loss: 0.9734
# D(x): 0.9552, D(G(z)): 0.3359
# ------------------------------
# Epoch: [0/1], Batch Num: [10100/12500]
# Discriminator Loss: 0.3586, Generator Loss: 1.0257
# D(x): 0.9927, D(G(z)): 0.2936
# ------------------------------
# Epoch: [0/1], Batch Num: [10150/12500]
# Discriminator Loss: 0.1975, Generator Loss: 2.3793
# D(x): 0.9986, D(G(z)): 0.1716
# ------------------------------
# Epoch: [0/1], Batch Num: [10200/12500]
# Discriminator Loss: 0.8246, Generator Loss: 1.2020
# D(x): 0.7982, D(G(z)): 0.3211
# ------------------------------
# Epoch: [0/1], Batch Num: [10250/12500]
# Discriminator Loss: 0.4175, Generator Loss: 1.3101
# D(x): 0.9993, D(G(z)): 0.3309
# ------------------------------
# Epoch: [0/1], Batch Num: [10300/12500]
# Discriminator Loss: 0.6087, Generator Loss: 1.7730
# D(x): 0.8660, D(G(z)): 0.3289
# ------------------------------
# Epoch: [0/1], Batch Num: [10350/12500]
# Discriminator Loss: 0.4799, Generator Loss: 1.8801
# D(x): 0.9998, D(G(z)): 0.3266
# ------------------------------
# Epoch: [0/1], Batch Num: [10400/12500]
# Discriminator Loss: 0.3599, Generator Loss: 1.0593
# D(x): 0.9949, D(G(z)): 0.2912
# ------------------------------
# Epoch: [0/1], Batch Num: [10450/12500]
# Discriminator Loss: 0.2251, Generator Loss: 2.0068
# D(x): 0.9990, D(G(z)): 0.1978
# ------------------------------
# Epoch: [0/1], Batch Num: [10500/12500]
# Discriminator Loss: 0.1152, Generator Loss: 1.3151
# D(x): 0.9880, D(G(z)): 0.0962
# ------------------------------
# Epoch: [0/1], Batch Num: [10550/12500]
# Discriminator Loss: 0.6400, Generator Loss: 1.3563
# D(x): 0.7513, D(G(z)): 0.2142
# ------------------------------
# Epoch: [0/1], Batch Num: [10600/12500]
# Discriminator Loss: 0.7747, Generator Loss: 1.4319
# D(x): 0.9500, D(G(z)): 0.4777
# ------------------------------
# Epoch: [0/1], Batch Num: [10650/12500]
# Discriminator Loss: 1.1106, Generator Loss: 1.1879
# D(x): 0.6752, D(G(z)): 0.4390
# ------------------------------
# Epoch: [0/1], Batch Num: [10700/12500]
# Discriminator Loss: 0.6248, Generator Loss: 1.3110
# D(x): 0.8458, D(G(z)): 0.3335
# ------------------------------
# Epoch: [0/1], Batch Num: [10750/12500]
# Discriminator Loss: 0.4868, Generator Loss: 2.4144
# D(x): 0.7482, D(G(z)): 0.1223
# ------------------------------
# Epoch: [0/1], Batch Num: [10800/12500]
# Discriminator Loss: 0.4645, Generator Loss: 1.9709
# D(x): 0.7971, D(G(z)): 0.1009
# ------------------------------
# Epoch: [0/1], Batch Num: [10850/12500]
# Discriminator Loss: 0.3409, Generator Loss: 1.3691
# D(x): 0.9948, D(G(z)): 0.2807
# ------------------------------
# Epoch: [0/1], Batch Num: [10900/12500]
# Discriminator Loss: 0.3778, Generator Loss: 1.4752
# D(x): 0.9766, D(G(z)): 0.2950
# ------------------------------
# Epoch: [0/1], Batch Num: [10950/12500]
# Discriminator Loss: 1.6392, Generator Loss: 1.2072
# D(x): 0.4693, D(G(z)): 0.4459
# ------------------------------
# Epoch: [0/1], Batch Num: [11000/12500]
# Discriminator Loss: 0.5020, Generator Loss: 1.8268
# D(x): 0.8275, D(G(z)): 0.1881
# ------------------------------
# Epoch: [0/1], Batch Num: [11050/12500]
# Discriminator Loss: 0.6674, Generator Loss: 1.7040
# D(x): 0.7788, D(G(z)): 0.2743
# ------------------------------
# Epoch: [0/1], Batch Num: [11100/12500]
# Discriminator Loss: 0.7472, Generator Loss: 1.2779
# D(x): 0.7559, D(G(z)): 0.2547
# ------------------------------
# Epoch: [0/1], Batch Num: [11150/12500]
# Discriminator Loss: 0.5451, Generator Loss: 1.7907
# D(x): 0.8456, D(G(z)): 0.2580
# ------------------------------
# Epoch: [0/1], Batch Num: [11200/12500]
# Discriminator Loss: 0.4570, Generator Loss: 1.2480
# D(x): 0.8942, D(G(z)): 0.2755
# ------------------------------
# Epoch: [0/1], Batch Num: [11250/12500]
# Discriminator Loss: 0.6154, Generator Loss: 1.4088
# D(x): 0.8143, D(G(z)): 0.2384
# ------------------------------
# Epoch: [0/1], Batch Num: [11300/12500]
# Discriminator Loss: 0.6799, Generator Loss: 2.2710
# D(x): 0.7309, D(G(z)): 0.1778
# ------------------------------
# Epoch: [0/1], Batch Num: [11350/12500]
# Discriminator Loss: 0.3195, Generator Loss: 1.7688
# D(x): 0.9363, D(G(z)): 0.2174
# ------------------------------
# Epoch: [0/1], Batch Num: [11400/12500]
# Discriminator Loss: 0.8812, Generator Loss: 1.3700
# D(x): 0.7383, D(G(z)): 0.2492
# ------------------------------
# Epoch: [0/1], Batch Num: [11450/12500]
# Discriminator Loss: 0.7155, Generator Loss: 1.7889
# D(x): 0.7555, D(G(z)): 0.2940
# ------------------------------
# Epoch: [0/1], Batch Num: [11500/12500]
# Discriminator Loss: 1.0813, Generator Loss: 1.7026
# D(x): 0.8241, D(G(z)): 0.3760
# ------------------------------
# Epoch: [0/1], Batch Num: [11550/12500]
# Discriminator Loss: 0.0909, Generator Loss: 2.6251
# D(x): 0.9870, D(G(z)): 0.0738
# ------------------------------
# Epoch: [0/1], Batch Num: [11600/12500]
# Discriminator Loss: 0.1916, Generator Loss: 1.9306
# D(x): 0.9918, D(G(z)): 0.1567
# ------------------------------
# Epoch: [0/1], Batch Num: [11650/12500]
# Discriminator Loss: 1.5139, Generator Loss: 1.7651
# D(x): 0.4511, D(G(z)): 0.1502
# ------------------------------
# Epoch: [0/1], Batch Num: [11700/12500]
# Discriminator Loss: 0.5146, Generator Loss: 2.7605
# D(x): 0.7992, D(G(z)): 0.1050
# ------------------------------
# Epoch: [0/1], Batch Num: [11750/12500]
# Discriminator Loss: 0.1731, Generator Loss: 2.3301
# D(x): 1.0000, D(G(z)): 0.1586
# ------------------------------
# Epoch: [0/1], Batch Num: [11800/12500]
# Discriminator Loss: 1.2097, Generator Loss: 1.1744
# D(x): 0.8652, D(G(z)): 0.5756
# ------------------------------
# Epoch: [0/1], Batch Num: [11850/12500]
# Discriminator Loss: 0.4263, Generator Loss: 1.0530
# D(x): 0.8938, D(G(z)): 0.2562
# ------------------------------
# Epoch: [0/1], Batch Num: [11900/12500]
# Discriminator Loss: 0.6099, Generator Loss: 1.6636
# D(x): 0.8250, D(G(z)): 0.2623
# ------------------------------
# Epoch: [0/1], Batch Num: [11950/12500]
# Discriminator Loss: 0.2366, Generator Loss: 1.6993
# D(x): 0.9850, D(G(z)): 0.1929
# ------------------------------
# Epoch: [0/1], Batch Num: [12000/12500]
# Discriminator Loss: 0.4113, Generator Loss: 1.1885
# D(x): 0.9262, D(G(z)): 0.2685
# ------------------------------
# Epoch: [0/1], Batch Num: [12050/12500]
# Discriminator Loss: 2.3729, Generator Loss: 1.6613
# D(x): 0.7155, D(G(z)): 0.6414
# ------------------------------
# Epoch: [0/1], Batch Num: [12100/12500]
# Discriminator Loss: 0.6111, Generator Loss: 1.6566
# D(x): 0.7658, D(G(z)): 0.2060
# ------------------------------
# Epoch: [0/1], Batch Num: [12150/12500]
# Discriminator Loss: 0.2499, Generator Loss: 1.8428
# D(x): 1.0000, D(G(z)): 0.2186
# ------------------------------
# Epoch: [0/1], Batch Num: [12200/12500]
# Discriminator Loss: 0.7865, Generator Loss: 1.8506
# D(x): 0.6722, D(G(z)): 0.2169
# ------------------------------
# Epoch: [0/1], Batch Num: [12250/12500]
# Discriminator Loss: 0.4820, Generator Loss: 1.6087
# D(x): 0.9123, D(G(z)): 0.2872
# ------------------------------
# Epoch: [0/1], Batch Num: [12300/12500]
# Discriminator Loss: 1.1167, Generator Loss: 2.0067
# D(x): 0.5726, D(G(z)): 0.1371
# ------------------------------
# Epoch: [0/1], Batch Num: [12350/12500]
# Discriminator Loss: 0.4938, Generator Loss: 1.1809
# D(x): 0.8505, D(G(z)): 0.2651
# ------------------------------
# Epoch: [0/1], Batch Num: [12400/12500]
# Discriminator Loss: 0.4488, Generator Loss: 2.1566
# D(x): 0.8295, D(G(z)): 0.1506
# ------------------------------
# Epoch: [0/1], Batch Num: [12450/12500]
# Discriminator Loss: 0.4506, Generator Loss: 1.6589
# D(x): 0.9638, D(G(z)): 0.3207
# ------------------------------
# Training finished

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(d_errors) + 1)
plt.figure(figsize=(10, 10))

# discriminator and generator errors
plt.subplot(2, 1, 1)
plt.plot(epochs, torch.tensor(d_errors).detach().numpy(), label='Discriminator Error', marker='o')
plt.plot(epochs, torch.tensor(g_errors).detach().numpy(), label='Generator Error', marker='x')
plt.xlabel('Epochs')
plt.ylabel('Error')
plt.title('Discriminator and Generator Errors')
plt.legend()

# discriminator predictions
plt.subplot(2, 1, 2)
plt.plot(epochs, torch.tensor(d_pred_real_means).detach().numpy(), label='Real Mean', marker='o')
plt.plot(epochs, torch.tensor(d_pred_fake_means).detach().numpy(), label='Fake Mean', marker='x')
plt.xlabel('Epochs')
plt.ylabel('Mean')
plt.title('Discriminator Predictions')
plt.legend()

plt.tight_layout()
plt.show()
